# %% [markdown]
# ## Notebook 01:
# ### Limpieza inicial de datos.
#
# Las tareas realizadas son:
#
# -Correccion de nombres, caracteres especiales, formato de datos.
#
# -Estandarización de Precios, por metro cuadrado.
#
# -Despliegue de columnas dummies según listas extraídas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import seaborn as sns
import re
import warnings
pd.set_option('display.max_columns', None) #Para mostrar todas las columnas

df = pd.read_csv('../data/raw_database_urbania.csv')
df.drop(['Unnamed: 0','Unnamed: 0.1'],inplace=True,axis=1)

#Columnas a reemplazar.
nuevas_cols = ['Adicionales', 'Ambientes', 'Antiguedad', 'Anunciante','Area_Terreno','Balneario','NroBanios',
               'Nro_pisos','Cocheras','Descripcion','Direccion','Disposicion','Dormitorios','EsCondominio',
              'Estado de Inmueble', 'Fecha_pub', 'Fila', 'Fondo','Frente', 'Generales', 'Luminosidad', 
               'Mantenimiento', 'Mascotas','Medidas','NoTieneAlgunDatoExtra','Pisos_construibles','TipoPuertaCochera',
               'Precio','Referencia','Servicios','Tipo','TipoCochera','Ubicacion','Urbaniz',
               'Uso_comercial','Uso_profesional','latitud','longitud','Area_constr','Area_total','Areas_comunes']

df.columns = nuevas_cols

# %% [markdown]
# ### Corrigiendo malos formatos.

# %%
df.Dormitorios = df.Dormitorios.replace({'5 a mÃ¡s':'5+'}) #Reemplazo

#Usamos expresiones regulares para corregir algunas columnas. 
df['Antiguedad'] = df['Antiguedad'].str.extract('(\d)', expand = True).astype('float32')

#Limpiar area de m2
pattern_m2 = '(\d{0,3}.?)'
for column_m2 in ['Area_constr_m2','Area_constr','Area_Terreno']:
    df[column_m2] = df[column_m2].str.extract(pattern_m2)

# %%
dict_replacement = {"Ã³":"o","Ã±":"ni","Ã©":"e",
                    "Ã\xad":"i","Ã\x81":"A","Ã":"a","\\":"n","aº":"u","Ã¼":"u","¼":"u",
                    "Acceso para personas con discapacidad":"Acceso personas discapacidad",
                   "anx81rea ":"Area","\\r":" " ,"a¡":"a",'"':'',',':'','\n':'','\t':'','    ':'','  ':''}

for word, initial in dict_replacement.items():
    df['Servicios'] = df['Servicios'].str.replace(word, initial)
    df['Ambientes'] = df['Ambientes'].str.replace(word,initial)
    df['Areas_comunes'] = df['Areas_comunes'].str.replace(word,initial)
    df['Generales'] = df['Generales'].str.replace(word,initial)
    df['Adicionales'] = df['Adicionales'].str.replace(word,initial)
    df['Descripcion'] = df['Descripcion'].str.replace(word,initial)
    df['longitud'] = df['longitud'].str.replace(word,initial)
    df['latitud'] = df['latitud'].str.replace(word,initial)

# %%
drop_condominio = df[df.latitud.isna()].index
df.drop(drop_condominio,inplace=True,axis=0)

# %%
df['Ubicacion'] = df['Ubicacion'].replace({'BreÃ±a-Lima':'Brenia-Lima', 'San Vicente De CaÃ±ete-Lima':'Caniete-Lima',
                                          'PariÃ±as-Piura':'Parianias-Piura','Los BaÃ±os Del Inca-Cajamarca':'Los Banios Del Inca-Cajamarca',
                                          'CaÃ±ete-Lima':'Caniete-Lima'})

# %%
df['Ubicacion'] = df['Ubicacion'].str.replace(' ','')  #Para que no existan discordancias entre los strings
dist_prov = df['Ubicacion'].str.extractall(r'(\w*?)?-(\w*)')
dist_prov.columns = ['Distrito','Provincia']
dist_prov.reset_index(inplace = True)
dist_prov.drop(columns = ['match'],inplace=True)
dist_prov.set_index('level_0',inplace=True)

# %%
#Haré split a las columnas que tienen valores como listas.
ola1 = df['Servicios'].str.extractall('(\[\'\w*\s?\w*?\s?\w*?\'),?\]?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?')
ola2 = df['Ambientes'].str.extractall('(\[\'\w*\s?\w*?\s?\w*?\'),?\]?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?')
ola3 = df['Areas_comunes'].str.extractall('(\[\'\w*\s?\w*?\s?\w*?\'),?\]?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?')
ola4 = df['Generales'].str.extractall('(\[\'\w*\s?\w*?\s?\w*?\'),?\]?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?')
ola5 = df['Adicionales'].str.extractall('(\[\'\w*\s?\w*?\s?\w*?\'),?\]?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?,?\s?(\'\w*\s?\w*?\s?\w*?\')?\]?')

# %%
#Hacer el reemplazo para solo una moneda
df['Precio']=df['Precio'].str.replace(",","")
index_casas_soles = df[(df['Precio'].str.startswith('US') == False) & (df['Precio'].str.startswith('Consultar') == False)].index
#Hasta acà los tengo almacenados en memoria.

# %%
#Limpio los US$ y S/ solo seleccionando los digits con regex
df['Precio'] = df['Precio'].str.extract('(\d{0,3},?\d{0,3},?\d{1,3}$)')

# %% [markdown]
# Ahora haremos join a las tablas que hemos creado

# %%
tipo_de_cambio_actual = 3.37
warnings.filterwarnings('ignore')
df['Precio'] = df['Precio'].astype('float64')
df.iloc[index_casas_soles - 1]['Precio'] = df.iloc[index_casas_soles -1]['Precio'].apply(lambda x: x*tipo_de_cambio_actual)

# %%
df['Area_constr_m2'] = df['Area_constr_m2'].astype('float64') 
df['Area_total_m2'] = df['Area_total_m2'].astype('float64')
df['Area_Terreno_m2'] = df['Area_Terreno_m2'].astype('float64')

# %% [markdown]
# plt.figure(figsize = (10,8))
# ax = sns.scatterplot(x='Area_total_m2',y='Precio',data= df)
#
# y_max = df['Precio'].max()
# ticks = [0, 0.25*y_max, 0.5*y_max, 0.75*y_max, y_max]
#
# ax.set_ylim(ax.get_ylim()) # set second y axis to have the same limits as the first y axis
# ax.set_yticks(ticks)
# ax.set_yticklabels(ticks) # set the labels
# ax.grid(True)

# %%
df.head()
# Out:
#     Adicionales                                          Ambientes  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3  ['Parrilla']  ['anx81tico' 'Banio de servicio' 'Banio de vis...
# 4  ['Desagaue']  ['Balcon' 'Banio de servicio' 'Banio de visita...
#
#    Antiguedad              Anunciante Area_Terreno Balneario  NroBanios  \
# 0         NaN            ENACORP S.A.          NaN       NaN        NaN
# 1         NaN                    DPI           NaN       NaN        NaN
# 2         NaN           No disponible          NaN       NaN        NaN
# 3         5.0  Valentinoinmobiliaria           NaN       NaN        4.0
# 4         5.0           No disponible    183.00 m2       NaN        5.0
#
#    Nro_pisos  Cocheras                                        Descripcion  \
# 0        NaN       NaN   ENACORP presenta Condominio Club Casas del Va...
# 1        NaN       NaN   TU CASA LA MEJOR INVERSIaN Casas con la mejo...
# 2        NaN       NaN   EXCELENTE OPORTUNIDAD DE INVERTIR :inmueble e...
# 3        2.0       3.0   Excelente opcion para vivir en una de las mej...
# 4        3.0       1.0   HERMOSA CASA A ESPALDA DE FUTURA AVENIDA PROL...
#
#                                            Direccion Disposicion Dormitorios  \
# 0  Av. San Juan s/n - Alt. Km. 30 Pan. Norte - Ca...         NaN         NaN
# 1  Altura km 39.5 Antigua Panamericana Sur Lurin,...         NaN         NaN
# 2                    Lima- BreÃ±a BreÃ±a, Lima, Lima         NaN           4
# 3  Malecon Monte Bello 5 La Molina, La Planicie, ...      Frente           3
# 4  Mz. O2 Lt. 03 Urb. San Antonio De Carapongo 2 ...      Frente          5+
#
#   EsCondominio Estado de Inmueble              Fecha_pub  Fila  Fondo  Frente  \
# 0           Si                NaN  Publicado el 18.09.19   NaN    NaN     NaN
# 1           Si                NaN  Publicado el 16.09.19   NaN    NaN     NaN
# 2          NaN                NaN  Publicado el 19.09.19   NaN    NaN     NaN
# 3          NaN          Excelente  Publicado el 19.09.19   NaN    NaN     NaN
# 4          NaN          Excelente  Publicado el 28.08.19   NaN   12.0     9.0
#
#                                            Generales   Luminosidad  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN  Muy luminoso
# 4  ['Centros comerciales cercanos' 'Colegios cerc...  Muy luminoso
#
#   Mantenimiento Mascotas Medidas NoTieneAlgunDatoExtra  Pisos_construibles  \
# 0           NaN      NaN     NaN                   NaN                 NaN
# 1           NaN      NaN     NaN                   NaN                 NaN
# 2           NaN      NaN     NaN           NingunValor                 NaN
# 3           NaN       Si     NaN                   NaN                 NaN
# 4           NaN       Si     NaN                   NaN                 4.0
#
#   TipoPuertaCochera    Precio                            Referencia  \
# 0               NaN  175000.0                                   NaN
# 1               NaN  147000.0                                   NaN
# 2               NaN  185000.0                                   NaN
# 3       AutomÃ¡tico  885000.0                                   NaN
# 4            Manual  150000.0  A una cuadra de Colegio Panamericano
#
#                                            Servicios                Tipo  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN  Casa en condominio
# 3                          ['Agua' 'Luz' 'Telefono']                Casa
# 4  ['Agua' 'Luz' 'Telefono' 'Cable' 'Internet' 'G...                Casa
#
#   TipoCochera        Ubicacion                   Urbaniz Uso_comercial  \
# 0         NaN              NaN                       NaN           NaN
# 1         NaN              NaN                       NaN           NaN
# 2         NaN      Brenia-Lima                       NaN           NaN
# 3   Paralelas    LaMolina-Lima               La Planicie            No
# 4         NaN  Lurigancho-Lima  San Antonio De Carapongo            Si
#
#   Uso_profesional            latitud            longitud Area_constr  \
# 0             NaN    11.859273499243    -77.086804881176         NaN
# 1             NaN         12.2526278         -76.884032          NaN
# 2             NaN  12.05705300000000  -77.05168340000000   213.00 m2
# 3             NaN  12.07723240000000  -76.92949390000000   450.00 m2
# 4              Si  12.00502154878552  -76.87265686505832   350.00 m2
#
#   Area_total                                      Areas_comunes  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2  128.00 m2                                                NaN
# 3  600.00 m2  ['Areade BBQ' 'Areadeportiva' 'Hall de ingreso...
# 4  183.00 m2                                                NaN
#
#    Area_constr_m2  Area_total_m2  Area_Terreno_m2
# 0             NaN            NaN              NaN
# 1             NaN            NaN              NaN
# 2           213.0          128.0              NaN
# 3           450.0          600.0              NaN
# 4           350.0          183.0            183.0

# %% [markdown]
# ##### Outliers

# %%
index_ = df[(df['Precio']<=10000)&(df['Ubicacion']=='Cusco-Cusco')].index #Los que tienes de ubicación Cusco
index_2 = df[(df['Precio']<=10000)].index #Los que tiene un precio que no es lógico

##Corrigiendo los precios que no veo que sean lógicos...
a = df[df['Precio']<=10000]['Precio']*df[(df['Precio']<=10000)]['Area_total_m2'] #Corrijo ese precio (m2*Precio(m2))

df.iloc[index_2]['Precio'] = a #Reemplazo los precios que he corregido por sus valores en general.

# %% [markdown]
# ##### Asunciones:
#
# - Las variables más importantes son:
#     - Tipo_Casa
#     - Dormitorios
#     - Area_constr
#     - Distrito
#     - Departamento
#     - Estado_inmueble
#     - Ambientes

# %%
def merge_my_dummies(df_):
    """
    En los datos crudos existe una columna con la lista de features extras característicos del inmueble.
    Esta función sacará cada valor de esos features y creará una columna por cada feature.
    
    Para ordenar mis dummies voy a tener que:

    1.- Sacar una lista de valores únicos para cada nombre comenzando desde adelante.
    
    2.- Iterar por sobre cada columna y cada elemento de la lista única, matcheando cuando los nombres son iguales.

    3.- En cada iteración ubicar las columnas iguales y sumarlas entre sí

    4.- Esta última suma, agregarla a un diccionario y posteriormente a un df
    """
    df_cols = list(df_.columns) #Las columnas en lista
    data = pd.get_dummies(df_, columns = df_cols) #Hago dummies
    data_cols = list(data.columns)
    cols_limpias = [w.replace('[','') for w in data_cols] #Limpio los nombres
    lista_unica_elem = list(set(nombre_col.split('_')[1] for nombre_col in cols_limpias)) #Hago lista única
    dicc_inter = {}
    for nombre_col in lista_unica_elem:
        cols_to_sum = data.columns[data.columns.str.contains(nombre_col)] #para cada iteración agarra las cols que contienen lo q quiero
        series_to_join = data[cols_to_sum].iloc[:,:].sum(axis = 1) #Acà tengo la serie
        dicc_inter[nombre_col] = series_to_join #Lo agrego a un dict
    dataframe = pd.DataFrame.from_dict(dicc_inter) #Lo convierto a un dframe
    return dataframe

# %%
df_servicios = merge_my_dummies(df1)
df_ambientes = merge_my_dummies(df2)
df_arcomunes = merge_my_dummies(df3)
df_generales = merge_my_dummies(df4)
df_adicional = merge_my_dummies(df5)

# %% [markdown]
# Agregamos esta data al df original

# %%
#Todos los features extras en un dataframe.
df_features = pd.concat([df_ambientes, df_servicios,df_arcomunes, df_generales, df_adicional], axis=1, sort=False)
df_features.fillna('NaN', inplace = True)
df_features.head()
# Out:
#         'Sala de estar' 'Walking Closet' 'Escritorio' 'Sala' 'Kitchenette'  \
#   match
# 3 0                   0                0            0      0             0
# 4 0                   0                0            0      0             0
# 5 0                   0                0            0      0             0
# 6 0                   0                0            0      0             0
# 7 0                   1                0            1      1             0
#
#         'Banio de visitas' 'Patio' 'anx81tico' 'Closet' 'Comedor diario'  \
#   match
# 3 0                      1       0           1        0                1
# 4 0                      1       0           0        0                1
# 5 0                      1       0           0        0                1
# 6 0                      1       0           0        0                1
# 7 0                      1       1           0        1                1
#
#         'Balcon' 'Cuarto de servicio' 'Banio de servicio' 'Lavanderanxada'  \
#   match
# 3 0            0                    1                   1                0
# 4 0            1                    1                   1                0
# 5 0            1                    1                   1                0
# 6 0            0                    1                   1                0
# 7 0            1                    1                   1                1
#
#         'Jardanxadn Interno' 'Deposito' 'Cocina' 'Comedor'  \
#   match
# 3 0                        0          1        1         1
# 4 0                        0          1        1         1
# 5 0                        0          0        1         1
# 6 0                        0          0        1         1
# 7 0                        1          1        1         1
#
#         'Banio independiente' 'Terraza' 'Sotano' 'Cable'  \
#   match
# 3 0                         0         0        0       0
# 4 0                         0         0        0       1
# 5 0                         0         0        0       1
# 6 0                         0         0        0       1
# 7 0                         0         1        0       0
#
#         'Servicio de Limpieza' 'Conexion a gas' 'Sistema de seguridad'  \
#   match
# 3 0                          0                0                      0
# 4 0                          1                0                      1
# 5 0                          0                1                      1
# 6 0                          0                0                      0
# 7 0                          0                0                      0
#
#         'Internet' 'Luz' 'Telefono' 'Agua' 'Guardiananxada' 'Areadeportiva'  \
#   match
# 3 0              0     1          1      1                0               1
# 4 0              1     1          1      1                1             NaN
# 5 0              1     1          1      1                1             NaN
# 6 0              1     1          1      1                0               0
# 7 0              0     1          0      1                0             NaN
#
#         'Juegos para ninios' 'Club House' 'Parque interno' 'Areade sauna'  \
#   match
# 3 0                        0            0                0              0
# 4 0                      NaN          NaN              NaN            NaN
# 5 0                      NaN          NaN              NaN            NaN
# 6 0                        0            0                0              0
# 7 0                      NaN          NaN              NaN            NaN
#
#         'Piscina' 'Gimnasio' 'Jardanxadn' 'Solarium' 'anx81reas verdes'  \
#   match
# 3 0             0          0            1          0                  0
# 4 0           NaN        NaN          NaN        NaN                NaN
# 5 0           NaN        NaN          NaN        NaN                NaN
# 6 0             0          0            0          0                  1
# 7 0           NaN        NaN          NaN        NaN                NaN
#
#         'Sala de internet' 'Hall de ingreso' 'Guarderanxada' 'Areade BBQ'  \
#   match
# 3 0                      0                 1               0            1
# 4 0                    NaN               NaN             NaN          NaN
# 5 0                    NaN               NaN             NaN          NaN
# 6 0                      0                 1               0            0
# 7 0                    NaN               NaN             NaN          NaN
#
#         'Sala de cine' 'Parques cercanos' 'Centros comerciales cercanos'  \
#   match
# 3 0                  0                NaN                            NaN
# 4 0                NaN                  1                              1
# 5 0                NaN                  1                              0
# 6 0                  0                  1                              1
# 7 0                NaN                  1                              1
#
#         'Acceso personas discapacidad' 'Frente al mar' 'Colegios cercanos'  \
#   match
# 3 0                                NaN             NaN                 NaN
# 4 0                                  1               0                   1
# 5 0                                  0               0                   1
# 6 0                                  0               0                   1
# 7 0                                  0               0                   1
#
#         'Ingreso independiente' 'Cerca al mar' 'Aire acondicionado'  \
#   match
# 3 0                         NaN            NaN                    0
# 4 0                           0              0                    0
# 5 0                           0              0                    1
# 6 0                           0              0                    0
# 7 0                           0              0                    0
#
#         'Equipado' 'Portero electrico' 'Chimenea' 'Terma' 'Cerco Electrico'  \
#   match
# 3 0              0                   0          0       0                 0
# 4 0              0                   0          0       0                 0
# 5 0              1                   1          1       1                 0
# 6 0              0                   1          0       0                 1
# 7 0              0                   0          0       0                 0
#
#         'Amoblado' 'Desagaue' 'Intercomunicador' 'Jacuzzi' 'Sauna' 'Parrilla'  \
#   match
# 3 0              0          0                  0         0       0          1
# 4 0              0          1                  0         0       0          0
# 5 0              1          1                  1         1       1          1
# 6 0              0          1                  0         0       0          1
# 7 0              0          0                  1         0       0          0
#
#         'Cocina con reposteros' 'Calefaccion'
#   match
# 3 0                           0             0
# 4 0                           0             0
# 5 0                           1             0
# 6 0                           1             0
# 7 0                           1             0

# %%
df_features.reset_index(inplace = True)

#Vamos a hacer el cambio de las variables para poder hacer el respectivo join
df_features.set_index('level_0', inplace = True)
df_features.index.names = ['index']
df.index.names = ['index']

df_final = df.join(df_features,how='inner')
df_final = df_final.join(dist_prov,how='inner')

#Ahora borraremos las columnas de las que vienen nuestras dummies:
df_final.drop(['Servicios','Ambientes','Areas_comunes','Adicionales','Generales'],axis=1,inplace=True)

# %% [markdown]
# ### Ahora que tenemos la data algo procesada, procederemos a limpiar los valores nulos en el siguiento notebook. La forma en la que quedaron los datos al final fue:

# %%
#Lo exporto en otro csv para poder limpiar los datos con más facilidad.
df_final.to_csv('../data/notebook01_output_data.csv')

# %%
df_final
# Out:
#       Antiguedad              Anunciante Area_Terreno Balneario  NroBanios  \
# 3            5.0  Valentinoinmobiliaria           NaN       NaN        4.0
# 4            5.0           No disponible    183.00 m2       NaN        5.0
# 5            NaN           No disponible   1518.00 m2       NaN        5.0
# 6            3.0           No disponible    400.00 m2       NaN        5.0
# 7            4.0           No disponible    290.55 m2       NaN        4.0
# ...          ...                     ...          ...       ...        ...
# 8712         2.0           No disponible          NaN       NaN        3.0
# 8713         4.0           No disponible          NaN       NaN        4.0
# 8714         3.0           No disponible          NaN       NaN        5.0
# 8715         9.0           No disponible          NaN       NaN        5.0
# 8716         1.0           No disponible          NaN       NaN        3.0
#
#       Nro_pisos  Cocheras                                        Descripcion  \
# 3           2.0       3.0   Excelente opcion para vivir en una de las mej...
# 4           3.0       1.0   HERMOSA CASA A ESPALDA DE FUTURA AVENIDA PROL...
# 5           3.0       4.0   Casa de estreno acabados de primera. Calle ce...
# 6           2.0       2.0   San Isidro-Corpac Propietario vende buen esta...
# 7           2.0       2.0   EXCELENTE UBICACIaN PARA HABITAR DE INMEDIAT...
# ...         ...       ...                                                ...
# 8712        2.0       3.0   Casa bien ubicada con parques muy cercanos. U...
# 8713        NaN       4.0   Excelente casa con proyecto aprobado para 5 c...
# 8714        NaN       3.0   Hall de ingreso sala comedor comedor de diari...
# 8715        NaN       5.0   Linda casa en casuarinas baja. super comoda e...
# 8716        2.0       2.0   Moderna casa con4 dormitorios en el segundo p...
#
#                                               Direccion Disposicion  \
# 3     Malecon Monte Bello 5 La Molina, La Planicie, ...      Frente
# 4     Mz. O2 Lt. 03 Urb. San Antonio De Carapongo 2 ...      Frente
# 5     El Pinar 120 , La Planicie 1era Etapa La Molin...      Frente
# 6     Espalda De La Cuadra 2 De La Avenida Guardia C...      Frente
# 7           Calle Tutumo Surco, Los Rosales, Lima, Lima      Frente
# ...                                                 ...         ...
# 8712  Cerca A La Av. Ayacucho Surco, Vista Alegre, L...         NaN
# 8713  Esquina La CaÃ±ada La Molina, La Molina Vieja,...         NaN
# 8714  Urb. Rinconada Alta La Molina, Rinconada Alta,...         NaN
# 8715  Casuarinas Baja Surco, Las Casuarinas Baja, Li...         NaN
# 8716  Cerca Al Club Lima Cricket Magdalena Del Mar, ...         NaN
#
#      Dormitorios EsCondominio Estado de Inmueble              Fecha_pub  Fila  \
# 3              3          NaN          Excelente  Publicado el 19.09.19   NaN
# 4             5+          NaN          Excelente  Publicado el 28.08.19   NaN
# 5              4          NaN          Excelente  Publicado el 06.08.19   NaN
# 6             5+          NaN          Muy bueno  Publicado el 28.08.19   NaN
# 7              4          NaN          Excelente  Publicado el 26.08.19   NaN
# ...          ...          ...                ...                    ...   ...
# 8712          5+          NaN              Bueno  Publicado el 20.08.19   NaN
# 8713           4          NaN              Bueno  Publicado el 20.08.19   NaN
# 8714          5+          NaN                NaN  Publicado el 20.08.19   NaN
# 8715           4          NaN                NaN  Publicado el 20.08.19   NaN
# 8716           4          NaN                NaN  Publicado el 20.08.19   NaN
#
#       Fondo  Frente   Luminosidad Mantenimiento Mascotas Medidas  \
# 3       NaN     NaN  Muy luminoso           NaN       Si     NaN
# 4      12.0     9.0  Muy luminoso           NaN       Si     NaN
# 5      53.0    29.0  Muy luminoso           NaN       Si     NaN
# 6       NaN     NaN  Muy luminoso           NaN       Si     NaN
# 7      29.0    10.0  Muy luminoso           NaN      NaN     NaN
# ...     ...     ...           ...           ...      ...     ...
# 8712    NaN     NaN           NaN           NaN      NaN     NaN
# 8713    NaN     NaN           NaN           NaN      NaN     NaN
# 8714    NaN     NaN           NaN          S/.1       Si     NaN
# 8715    NaN     NaN           NaN           NaN      NaN     NaN
# 8716    NaN     NaN           NaN           NaN      NaN     NaN
#
#      NoTieneAlgunDatoExtra  Pisos_construibles TipoPuertaCochera     Precio  \
# 3                      NaN                 NaN       AutomÃ¡tico   885000.0
# 4                      NaN                 4.0            Manual   150000.0
# 5                      NaN                 NaN       AutomÃ¡tico  1950000.0
# 6                      NaN                 5.0       AutomÃ¡tico      850.0
# 7                      NaN                 3.0       AutomÃ¡tico        NaN
# ...                    ...                 ...               ...        ...
# 8712                   NaN                 NaN               NaN   440000.0
# 8713                   NaN                 NaN               NaN  3168000.0
# 8714                   NaN                 NaN               NaN   850000.0
# 8715                   NaN                 NaN               NaN  6200000.0
# 8716                   NaN                 NaN               NaN   650000.0
#
#                                         Referencia                Tipo  \
# 3                                              NaN                Casa
# 4             A una cuadra de Colegio Panamericano                Casa
# 5     Cerca del Colegio Villa Maria y Club El Golf                Casa
# 6                          a 200 metros del Rambla                Casa
# 7                           Frente al Club Germano                Casa
# ...                                            ...                 ...
# 8712                       CERCA A LA AV. AYACUCHO                Casa
# 8713                            Esquina La CaÃ±ada                Casa
# 8714                           Urb. Rinconada Alta  Casa en condominio
# 8715                               Casuarinas baja                Casa
# 8716                    CERCA AL CLUB LIMA CRICKET                Casa
#
#      TipoCochera             Ubicacion                   Urbaniz  \
# 3      Paralelas         LaMolina-Lima               La Planicie
# 4            NaN       Lurigancho-Lima  San Antonio De Carapongo
# 5      Paralelas         LaMolina-Lima               La Planicie
# 6      Separadas        SanIsidro-Lima                    Corpac
# 7      Paralelas  SantiagoDeSurco-Lima               Los Rosales
# ...          ...                   ...                       ...
# 8712   Paralelas  SantiagoDeSurco-Lima              Vista Alegre
# 8713         NaN         LaMolina-Lima           La Molina Vieja
# 8714   Paralelas         LaMolina-Lima            Rinconada Alta
# 8715         NaN  SantiagoDeSurco-Lima       Las Casuarinas Baja
# 8716   Paralelas  MagdalenaDelMar-Lima                    Oyague
#
#      Uso_comercial Uso_profesional            latitud            longitud  \
# 3               No             NaN  12.07723240000000  -76.92949390000000
# 4               Si              Si  12.00502154878552  -76.87265686505832
# 5              NaN             NaN  12.06515005665533  -76.91061992222012
# 6               No              No  12.10456470000000  -77.05914080000000
# 7              NaN             NaN  12.13034765732427  -76.99702889044760
# ...            ...             ...                ...                 ...
# 8712           NaN             NaN  12.13513463946400    -76.995685100555
# 8713           NaN             NaN  12.07788032957700    -76.929614245892
# 8714           NaN             NaN  12.07790918077000  -76.92947544157501
# 8715           NaN             NaN  12.11967670000000         -76.9693468
# 8716           NaN             NaN  12.09927268814100  -77.06196273677101
#
#      Area_constr  Area_total  Area_constr_m2  Area_total_m2  Area_Terreno_m2  \
# 3      450.00 m2   600.00 m2           450.0          600.0              NaN
# 4      350.00 m2   183.00 m2           350.0          183.0            183.0
# 5      625.00 m2  1518.00 m2           625.0         1518.0           1518.0
# 6      378.00 m2   400.00 m2           378.0          400.0            400.0
# 7      297.50 m2   290.55 m2           297.0          290.0            290.0
# ...          ...         ...             ...            ...              ...
# 8712   150.00 m2   250.00 m2           150.0          250.0              NaN
# 8713   500.00 m2  2640.00 m2           500.0         2640.0              NaN
# 8714   283.00 m2   310.00 m2           283.0          310.0              NaN
# 8715   800.00 m2  2650.00 m2           800.0         2650.0              NaN
# 8716   277.00 m2   260.00 m2           277.0          260.0              NaN
#
#       match 'Sala de estar' 'Walking Closet' 'Escritorio' 'Sala'  \
# 3         0               0                0            0      0
# 4         0               0                0            0      0
# 5         0               0                0            0      0
# 6         0               0                0            0      0
# 7         0               1                0            1      1
# ...     ...             ...              ...          ...    ...
# 8712      0               0                0            1      1
# 8713      0               1                0            1      1
# 8714      0               1                0            1      0
# 8715      0               1                1            1      1
# 8716      0               1                0            1      1
#
#      'Kitchenette' 'Banio de visitas' 'Patio' 'anx81tico' 'Closet'  \
# 3                0                  1       0           1        0
# 4                0                  1       0           0        0
# 5                0                  1       0           0        0
# 6                0                  1       0           0        0
# 7                0                  1       1           0        1
# ...            ...                ...     ...         ...      ...
# 8712             0                  0       1           0        0
# 8713             0                  0       0           0        0
# 8714             0                  0       0           0        0
# 8715             0                  1       1           0        0
# 8716             0                  0       0           0        0
#
#      'Comedor diario' 'Balcon' 'Cuarto de servicio' 'Banio de servicio'  \
# 3                   1        0                    1                   1
# 4                   1        1                    1                   1
# 5                   1        1                    1                   1
# 6                   1        0                    1                   1
# 7                   1        1                    1                   1
# ...               ...      ...                  ...                 ...
# 8712                1        0                    1                   1
# 8713                1        0                    1                   1
# 8714                1        0                    1                   1
# 8715                1        0                    1                   1
# 8716                1        0                    1                   1
#
#      'Lavanderanxada' 'Jardanxadn Interno' 'Deposito' 'Cocina' 'Comedor'  \
# 3                   0                    0          1        1         1
# 4                   0                    0          1        1         1
# 5                   0                    0          0        1         1
# 6                   0                    0          0        1         1
# 7                   1                    1          1        1         1
# ...               ...                  ...        ...      ...       ...
# 8712                1                    1          0        1         1
# 8713                1                    0          0        1         1
# 8714                1                    0          0        1         1
# 8715                1                    1          0        1         1
# 8716                1                    1          0        1         1
#
#      'Banio independiente' 'Terraza' 'Sotano' 'Cable' 'Servicio de Limpieza'  \
# 3                        0         0        0       0                      0
# 4                        0         0        0       1                      1
# 5                        0         0        0       1                      0
# 6                        0         0        0       1                      0
# 7                        0         1        0       0                      0
# ...                    ...       ...      ...     ...                    ...
# 8712                     0         1        0     NaN                    NaN
# 8713                     0         1        0     NaN                    NaN
# 8714                     0         1        0       0                      0
# 8715                     0         1        1     NaN                    NaN
# 8716                     0         1        0     NaN                    NaN
#
#      'Conexion a gas' 'Sistema de seguridad' 'Internet' 'Luz' 'Telefono'  \
# 3                   0                      0          0     1          1
# 4                   0                      1          1     1          1
# 5                   1                      1          1     1          1
# 6                   0                      0          1     1          1
# 7                   0                      0          0     1          0
# ...               ...                    ...        ...   ...        ...
# 8712              NaN                    NaN        NaN   NaN        NaN
# 8713              NaN                    NaN        NaN   NaN        NaN
# 8714                0                      0          0     0          0
# 8715              NaN                    NaN        NaN   NaN        NaN
# 8716              NaN                    NaN        NaN   NaN        NaN
#
#      'Agua' 'Guardiananxada' 'Areadeportiva' 'Juegos para ninios'  \
# 3         1                0               1                    0
# 4         1                1             NaN                  NaN
# 5         1                1             NaN                  NaN
# 6         1                0               0                    0
# 7         1                0             NaN                  NaN
# ...     ...              ...             ...                  ...
# 8712    NaN              NaN               0                    0
# 8713    NaN              NaN               0                    0
# 8714      0                1               0                    0
# 8715    NaN              NaN               0                    0
# 8716    NaN              NaN               0                    0
#
#      'Club House' 'Parque interno' 'Areade sauna' 'Piscina' 'Gimnasio'  \
# 3               0                0              0         0          0
# 4             NaN              NaN            NaN       NaN        NaN
# 5             NaN              NaN            NaN       NaN        NaN
# 6               0                0              0         0          0
# 7             NaN              NaN            NaN       NaN        NaN
# ...           ...              ...            ...       ...        ...
# 8712            0                0              0         0          0
# 8713            0                0              0         1          0
# 8714            0                0              0         1          0
# 8715            0                0              0         1          0
# 8716            0                0              0         0          0
#
#      'Jardanxadn' 'Solarium' 'anx81reas verdes' 'Sala de internet'  \
# 3               1          0                  0                  0
# 4             NaN        NaN                NaN                NaN
# 5             NaN        NaN                NaN                NaN
# 6               0          0                  1                  0
# 7             NaN        NaN                NaN                NaN
# ...           ...        ...                ...                ...
# 8712            1          0                  0                  0
# 8713            1          0                  0                  0
# 8714            1          0                  0                  0
# 8715            1          0                  0                  0
# 8716            1          0                  0                  0
#
#      'Hall de ingreso' 'Guarderanxada' 'Areade BBQ' 'Sala de cine'  \
# 3                    1               0            1              0
# 4                  NaN             NaN          NaN            NaN
# 5                  NaN             NaN          NaN            NaN
# 6                    1               0            0              0
# 7                  NaN             NaN          NaN            NaN
# ...                ...             ...          ...            ...
# 8712                 1               0            0              0
# 8713                 1               0            0              0
# 8714                 1               0            0              0
# 8715                 1               0            0              0
# 8716                 1               0            0              0
#
#      'Parques cercanos' 'Centros comerciales cercanos'  \
# 3                   NaN                            NaN
# 4                     1                              1
# 5                     1                              0
# 6                     1                              1
# 7                     1                              1
# ...                 ...                            ...
# 8712                NaN                            NaN
# 8713                NaN                            NaN
# 8714                NaN                            NaN
# 8715                NaN                            NaN
# 8716                NaN                            NaN
#
#      'Acceso personas discapacidad' 'Frente al mar' 'Colegios cercanos'  \
# 3                               NaN             NaN                 NaN
# 4                                 1               0                   1
# 5                                 0               0                   1
# 6                                 0               0                   1
# 7                                 0               0                   1
# ...                             ...             ...                 ...
# 8712                            NaN             NaN                 NaN
# 8713                            NaN             NaN                 NaN
# 8714                            NaN             NaN                 NaN
# 8715                            NaN             NaN                 NaN
# 8716                            NaN             NaN                 NaN
#
#      'Ingreso independiente' 'Cerca al mar' 'Aire acondicionado' 'Equipado'  \
# 3                        NaN            NaN                    0          0
# 4                          0              0                    0          0
# 5                          0              0                    1          1
# 6                          0              0                    0          0
# 7                          0              0                    0          0
# ...                      ...            ...                  ...        ...
# 8712                     NaN            NaN                    0          0
# 8713                     NaN            NaN                  NaN        NaN
# 8714                     NaN            NaN                    1          0
# 8715                     NaN            NaN                    1          0
# 8716                     NaN            NaN                    1          0
#
#      'Portero electrico' 'Chimenea' 'Terma' 'Cerco Electrico' 'Amoblado'  \
# 3                      0          0       0                 0          0
# 4                      0          0       0                 0          0
# 5                      1          1       1                 0          1
# 6                      1          0       0                 1          0
# 7                      0          0       0                 0          0
# ...                  ...        ...     ...               ...        ...
# 8712                   0          0       0                 0          0
# 8713                 NaN        NaN     NaN               NaN        NaN
# 8714                   0          0       0                 0          0
# 8715                   0          1       0                 0          0
# 8716                   0          0       0                 0          0
#
#      'Desagaue' 'Intercomunicador' 'Jacuzzi' 'Sauna' 'Parrilla'  \
# 3             0                  0         0       0          1
# 4             1                  0         0       0          0
# 5             1                  1         1       1          1
# 6             1                  0         0       0          1
# 7             0                  1         0       0          0
# ...         ...                ...       ...     ...        ...
# 8712          0                  0         0       0          1
# 8713        NaN                NaN       NaN     NaN        NaN
# 8714          0                  0         0       0          0
# 8715          0                  0         1       0          1
# 8716          0                  0         0       0          1
#
#      'Cocina con reposteros' 'Calefaccion'         Distrito Provincia
# 3                          0             0         LaMolina      Lima
# 4                          0             0       Lurigancho      Lima
# 5                          1             0         LaMolina      Lima
# 6                          1             0        SanIsidro      Lima
# 7                          1             0  SantiagoDeSurco      Lima
# ...                      ...           ...              ...       ...
# 8712                       0             0  SantiagoDeSurco      Lima
# 8713                     NaN           NaN         LaMolina      Lima
# 8714                       0             0         LaMolina      Lima
# 8715                       0             0  SantiagoDeSurco      Lima
# 8716                       0             0  MagdalenaDelMar      Lima
#
# [8149 rows x 108 columns]
