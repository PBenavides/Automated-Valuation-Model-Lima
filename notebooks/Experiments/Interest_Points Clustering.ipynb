# %%
import geopandas
import pandas as pd
import matplotlib.pyplot as plt
import osmnx as ox

from shapely.geometry import Point
peru_districts = geopandas.read_file('../../data/GeoShape_Distritos/DISTRITOS.shp')
interest_points = geopandas.read_file('../../data/GeoShape_Puntos_Interes/Puntos.shp')
parks = geopandas.read_file('../../data/GeoShape_Parques/Parques.shp')
interest_points
# Out:
#           osm_id             timestamp                   name  \
# 0      108064564  2013-07-09T22:30:04Z                   None
# 1      108161647  2014-05-03T07:11:20Z                   None
# 2      263385047  2011-09-07T07:57:10Z                   None
# 3      263631691  2013-10-09T11:36:41Z                   None
# 4      289315617  2012-07-24T18:54:24Z               Atocongo
# ...          ...                   ...                    ...
# 3739  2854483101  2014-05-13T06:49:34Z              El Rocoto
# 3740  2854486801  2014-05-13T06:55:24Z  El Rocoto,,Miraflores
# 3741  2854495301  2014-05-13T07:06:25Z    Trattolia Don Vitto
# 3742  2854537001  2014-05-13T07:24:52Z             Los Conroy
# 3743  2870467309  2014-05-20T14:17:34Z        Grafimundo S.A.
#
#                  type                        geometry
# 0     traffic_signals  POINT (278773.877 8661891.720)
# 1            crossing  POINT (278367.318 8665938.833)
# 2      turning_circle  POINT (275781.348 8662727.652)
# ...

# %%
lima_districts = peru_districts[peru_districts['DEPARTAMEN'] == 'LIMA']

# %%
fig, ax = plt.subplots(figsize=(18,12))
#lima_districts.plot(ax=ax)
parks.plot(ax=ax, color='green')
#interest_points.plot(ax=ax, color='red')
# Out:
# <AxesSubplot:>
